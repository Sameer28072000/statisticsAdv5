# %% [markdown]
# Q1. Calculate the 95% confidence interval for a sample of data with a mean of 50 and a standard deviation
# of 5 using Python. Interpret the results.

# %%
import scipy.stats as stats

sample_mean = 50
sample_std = 5
sample_size = 100  

confidence_level = 0.95
alpha = 1 - confidence_level

critical_value = stats.norm.ppf(1 - alpha / 2)

margin_of_error = critical_value * (sample_std / (sample_size ** 0.5))

lower_bound = sample_mean - margin_of_error
upper_bound = sample_mean + margin_of_error

print("Confidence Interval:", (lower_bound, upper_bound))
# Out:
# Confidence Interval: (49.02001800772997, 50.97998199227003)

# %% [markdown]
# Q2. Conduct a chi-square goodness of fit test to determine if the distribution of colors of M&Ms in a bag
# matches the expected distribution of 20% blue, 20% orange, 20% green, 10% yellow, 10% red, and 20%
# brown. Use Python to perform the test with a significance level of 0.05.

# %%
import numpy as np
import scipy.stats as stats

observed_counts = np.array([25, 30, 20, 14, 12, 18]) 
expected_counts = np.array([0.2, 0.2, 0.2, 0.1, 0.1, 0.2]) * np.sum(observed_counts) 

chi2_stat, p_value = stats.chisquare(observed_counts, f_exp=expected_counts)

alpha = 0.05
if p_value < alpha:
    print("Reject the null hypothesis.")
else:
    print("Fail to reject the null hypothesis.")

print("Chi-square statistic:", chi2_stat)
print("p-value:", p_value)
# Out:
# Fail to reject the null hypothesis.
# Chi-square statistic: 4.067226890756302
# p-value: 0.5397781266604327

# %% [markdown]
# Q3. Use Python to calculate the chi-square statistic and p-value for a contingency table with the following
# data:

# %%
import numpy as np
import scipy.stats as stats

observed_data = np.array([[20, 15], [10, 25], [15, 20]])

chi2_stat, p_value, _, _ = stats.chi2_contingency(observed_data)

print("Chi-square statistic:", chi2_stat)
print("p-value:", p_value)
# Out:
# Chi-square statistic: 5.833333333333334
# p-value: 0.05411376622282158

# %% [markdown]
# Q4. A study of the prevalence of smoking in a population of 500 individuals found that 60 individuals
# smoked. Use Python to calculate the 95% confidence interval for the true proportion of individuals in the
# population who smoke.

# %%
import statsmodels.stats.proportion as proportion

population_size = 500
observed_success = 60

sample_proportion = observed_success / population_size

confidence_level = 0.95
alpha = 1 - confidence_level
lower_bound, upper_bound = proportion.proportion_confint(observed_success, population_size, alpha=alpha, method='normal')

print("Confidence Interval:", (lower_bound, upper_bound))
# Out:
# Confidence Interval: (0.09151638887130707, 0.1484836111286929)

# %% [markdown]
# Q5. Calculate the 90% confidence interval for a sample of data with a mean of 75 and a standard deviation
# of 12 using Python. Interpret the results.

# %%
import scipy.stats as stats

sample_mean = 75
sample_std = 12
sample_size = 100 

confidence_level = 0.90
alpha = 1 - confidence_level

critical_value = stats.norm.ppf(1 - alpha / 2)

margin_of_error = critical_value * (sample_std / (sample_size ** 0.5))

lower_bound = sample_mean - margin_of_error
upper_bound = sample_mean + margin_of_error

print("Confidence Interval:", (lower_bound, upper_bound))
# Out:
# Confidence Interval: (73.02617564765823, 76.97382435234177)

# %% [markdown]
# Q6. Use Python to plot the chi-square distribution with 10 degrees of freedom. Label the axes and shade the
# area corresponding to a chi-square statistic of 15.

# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats as stats

df = 10

x = np.linspace(0, 30, 500)

y = stats.chi2.pdf(x, df)

plt.plot(x, y, label=f"Chi-square (df={df})")

x_shade = np.linspace(15, 30, 100)
y_shade = stats.chi2.pdf(x_shade, df)
plt.fill_between(x_shade, y_shade, 0, alpha=0.3, color='blue', label='Shaded Area')

plt.xlabel("Chi-square Statistic")
plt.ylabel("Probability Density")

plt.title("Chi-square Distribution")

plt.legend()

plt.show()

# %% [markdown]
# Q7. A random sample of 1000 people was asked if they preferred Coke or Pepsi. Of the sample, 520
# preferred Coke. Calculate a 99% confidence interval for the true proportion of people in the population who
# prefer Coke.

# %%
import statsmodels.stats.proportion as proportion

sample_size = 1000
observed_success = 520
sample_proportion = observed_success / sample_size

# Calculate the confidence interval
confidence_level = 0.99
alpha = 1 - confidence_level
lower_bound, upper_bound = proportion.proportion_confint(observed_success, sample_size, alpha=alpha, method='normal')

print("Confidence Interval:", (lower_bound, upper_bound))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[34], line 9
#       5 observed_success = 520
#       7 sample_proportion = observed_success / sample_size
# ----> 9 standard_error = sm.stats.proportion.std_prop(sample_proportion, sample_size)
#      11 confidence_level = 0.99
#      12 alpha = 1 - confidence_level
#
# AttributeError: module 'statsmodels.stats.api' has no attribute 'proportion'

# %% [markdown]
# Q8. A researcher hypothesizes that a coin is biased towards tails. They flip the coin 100 times and observe
# 45 tails. Conduct a chi-square goodness of fit test to determine if the observed frequencies match the
# expected frequencies of a fair coin. Use a significance level of 0.05.

# %%
import numpy as np
import scipy.stats as stats

observed_freq = np.array([45, 55])  
expected_freq = np.array([0.5, 0.5]) * np.sum(observed_freq)  

chi2_stat, p_value = stats.chisquare(observed_freq, f_exp=expected_freq)

alpha = 0.05
if p_value < alpha:
    print("Reject the null hypothesis.")
else:
    print("Fail to reject the null hypothesis.")

print("Chi-square statistic:", chi2_stat)
print("p-value:", p_value)
# Out:
# Fail to reject the null hypothesis.
# Chi-square statistic: 1.0
# p-value: 0.31731050786291115

# %% [markdown]
# Q9. A study was conducted to determine if there is an association between smoking status (smoker or
# non-smoker) and lung cancer diagnosis (yes or no). The results are shown in the contingency table below.
# Conduct a chi-square test for independence to determine if there is a significant association between
# smoking status and lung cancer diagnosis.

# %%
import numpy as np
import scipy.stats as stats

observed_data = np.array([[60, 140], [30, 170]])

chi2_stat, p_value, _, _ = stats.chi2_contingency(observed_data)

alpha = 0.05
if p_value < alpha:
    print("Reject the null hypothesis.  association between smoking status and lung cancer diagnosis.")
else:
    print("Fail to reject the null hypothesis. association between smoking status and lung cancer diagnosis.")

print("Chi-square statistic:", chi2_stat)
print("p-value:", p_value)
# Out:
# Reject the null hypothesis.  association between smoking status and lung cancer diagnosis.
# Chi-square statistic: 12.057347670250895
# p-value: 0.0005158863863703744
